# %%
# ==========================================
# Part F : Lasso Regression
# ==========================================

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# ------------------------------------------
# Load Dataset
# ------------------------------------------

df = pd.read_csv("../../datasets/house_regression_lab_dataset(in).csv")

# Independent Variables
X = df[["Area_sqft", "Bedrooms", "Age_years"]]

# Target Variable
y = df["Price_lakhs"]

# ------------------------------------------
# Split Dataset
# ------------------------------------------

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# ==========================================
# Linear Regression
# ==========================================

linear = LinearRegression()
linear.fit(X_train, y_train)

# ==========================================
# Ridge Regression
# ==========================================

ridge = Ridge(alpha=1.0)
ridge.fit(X_train, y_train)

# ==========================================
# Lasso Regression
# ==========================================

lasso = Lasso(alpha=1.0)

lasso.fit(X_train, y_train)

# ------------------------------------------
# 1. Lasso Intercept
# ------------------------------------------

print("Lasso Intercept (β0):")

print(lasso.intercept_)

# ------------------------------------------
# 2. Lasso Coefficients
# ------------------------------------------

print("\nLasso Coefficients")

print("Area_sqft :", lasso.coef_[0])

print("Bedrooms  :", lasso.coef_[1])

print("Age_years :", lasso.coef_[2])

# ------------------------------------------
# Lasso Regression Equation
# ------------------------------------------

print("\nLasso Regression Equation")

print(
    f"Price = {lasso.intercept_:.4f}"
    f" + ({lasso.coef_[0]:.4f} × Area_sqft)"
    f" + ({lasso.coef_[1]:.4f} × Bedrooms)"
    f" + ({lasso.coef_[2]:.4f} × Age_years)"
)

# ------------------------------------------
# Prediction
# ------------------------------------------

y_pred = lasso.predict(X_test)

# ------------------------------------------
# 3. Evaluation Metrics
# ------------------------------------------

mae = mean_absolute_error(y_test, y_pred)

mse = mean_squared_error(y_test, y_pred)

rmse = np.sqrt(mse)

r2 = r2_score(y_test, y_pred)

print("\nEvaluation Metrics")

print("MAE  =", mae)

print("MSE  =", mse)

print("RMSE =", rmse)

print("R²   =", r2)

# ------------------------------------------
# 4. Compare Linear, Ridge and Lasso
# ------------------------------------------

comparison = pd.DataFrame({

    "Feature": X.columns,

    "Linear": linear.coef_,

    "Ridge": ridge.coef_,

    "Lasso": lasso.coef_

})

print("\nCoefficient Comparison")

print(comparison)

# ------------------------------------------
# Prediction Table
# ------------------------------------------

result = pd.DataFrame({

    "Actual Price": y_test.values,

    "Predicted Price": y_pred,

    "Error": y_test.values - y_pred

})

print("\nPrediction Table")

print(result)
# Out:
# Lasso Intercept (β0):
# -0.7617535553459334
#
# Lasso Coefficients
# Area_sqft : 0.04597668333837638
# Bedrooms  : 0.0
# Age_years : -0.0
#
# Lasso Regression Equation
# Price = -0.7618 + (0.0460 × Area_sqft) + (0.0000 × Bedrooms) + (-0.0000 × Age_years)
#
# Evaluation Metrics
# MAE  = 3.9211206236761966
# MSE  = 18.67604807361642
# RMSE = 4.321579349452747
# R²   = 0.9958744835223602
#
# Coefficient Comparison
#      Feature    Linear     Ridge     Lasso
# 0  Area_sqft  0.046184  0.046017  0.045977
# 1   Bedrooms -0.504495 -0.314175  0.000000
# 2  Age_years -0.089506 -0.080843 -0.000000
#
# Prediction Table
#    Actual Price  Predicted Price     Error
# 0            81        84.295111 -3.295111
# 1           145       146.363633 -1.363633
# 2            42        38.318427  3.681573
# 3           238       233.719331  4.280669
# 4            98       104.984618 -6.984618
